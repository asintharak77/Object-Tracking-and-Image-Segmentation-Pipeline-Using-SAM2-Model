# %% [markdown]
# ## Object Tracking and Image Segmentation Pipeline Using SAM2 Model

# %% [markdown]
# ### Introduction
#
# This project presents an advanced image segmentation and object tracking pipeline using the SAM2 model, a solution for tasks requiring precise object detection and segmentation in video frames. The pipeline is designed to automate the process of tracking objects across multiple frames, predicting segmentation masks, and evaluating the accuracy of these predictions using COCO format metrics. It offers a reusable framework adaptable to different categories of objects.
#
# ### Implementation Details
#
# The core of this project is encapsulated in the ImageSegmentationPipeline class. This class integrates several components:
#
# 1. **Initialization and Setup:**
#
# - The class initializes the SAM2 model for both image and video predictions.
# - A temporary directory is created for storing intermediate files during processing.
#
# 2. **Utility Functions:**
#
# - Functions for directory management, clearing temporary folders, and image display are provided.
# - The ```show_mask``` and ```show_box``` methods allow visualization of segmentation masks and bounding boxes on images.
#
# 3. **Tracking and Visualization:**
#
# - The ```track_item_boxes``` method tracks objects across frames based on the bounding boxes provided.
# - The ```visualize_tracking``` method helps visualize the object tracking results.
#
# 4. **Image Processing:**
#
# - The ```process_img_png_mask``` method processes the mask of an image to extract bounding box coordinates.
# - The ```process_category method``` handles the entire workflow for a given category, including mask prediction, bounding box extraction, and saving the results.
#
# 5. **Evaluation:**
#
# - The ```evaluate_category``` method evaluates the predicted bounding boxes against the ground truth using COCO's evaluation tools, providing performance metrics for each category.
#
# 6. **Pipeline Execution:**
#
# - The ```run_pipeline``` method is the entry point for running the entire process on specified categories, from image processing to evaluation.

# %% [markdown]
# ### Importing necessary libraries

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import shutil
import json
from PIL import Image
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from torchvision import transforms

from sam2.build_sam import build_sam2
from sam2.automatic_mask_generator import SAM2AutomaticMaskGenerator
from sam2.sam2_image_predictor import SAM2ImagePredictor
from sam2.build_sam import build_sam2_video_predictor
# Out:
# C:\Users\HP\Desktop\Parallel_dots_assignment\segment-anything-2\sam2\modeling\sam\transformer.py:23: UserWarning: Flash Attention is disabled as it requires a GPU with Ampere (8.0) CUDA capability.
#   OLD_GPU, USE_FLASH_ATTN, MATH_KERNEL_ON = get_sdpa_settings()

# %% [markdown]
# ### Defining the Image Segmentation Pipeline Class

# %%
class ImageSegmentationPipeline:
    def __init__(self, model_cfg, checkpoint, device='cuda'):
        self.predictor_prompt = SAM2ImagePredictor(build_sam2(model_cfg, checkpoint))
        self.sam2 = build_sam2(model_cfg, checkpoint, device=device, apply_postprocessing=False)
        self.mask_generator = SAM2AutomaticMaskGenerator(self.sam2)
        self.predictor_vid = build_sam2_video_predictor(model_cfg, checkpoint, device=device)
        
        self.tempfolder = "./tempdir"
        self.create_if_not_exists(self.tempfolder)

    @staticmethod
    def create_if_not_exists(dirname):
        if not os.path.exists(dirname):
            os.makedirs(dirname)

    def cleardir(self, folder):
        filepaths = glob.glob(folder + "/*")
        for filepath in filepaths:
            os.unlink(filepath)

    def show_mask(self, mask, ax, obj_id=None, random_color=False):
        if random_color:
            color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
        else:
            cmap = plt.get_cmap("tab10")
            cmap_idx = 0 if obj_id is None else obj_id
            color = np.array([*cmap(cmap_idx)[:3], 0.6])
        h, w = mask.shape[-2:]
        mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
        ax.imshow(mask_image)

    def show_box(self, box, ax):
        x0, y0 = box[0], box[1]
        w, h = box[2] - box[0], box[3] - box[1]
        ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0, 0, 0, 0), linewidth=1))

    def track_item_boxes(self, imgpath1, imgpath2, img1boxclasslist, visualize=False):
        self.cleardir(self.tempfolder)
        shutil.copy(imgpath1, self.tempfolder + "/00000.jpg")
        shutil.copy(imgpath2, self.tempfolder + "/00001.jpg")

        inference_state = self.predictor_vid.init_state(video_path=self.tempfolder)
        self.predictor_vid.reset_state(inference_state)
        ann_frame_idx = 0

        for img1boxclass in img1boxclasslist:
            ([xmin, xmax, ymin, ymax], objectnumint) = img1boxclass
            box = np.array([xmin, ymin, xmax, ymax], dtype=np.float32)
            _, out_obj_ids, out_mask_logits = self.predictor_vid.add_new_points_or_box(
                inference_state=inference_state,
                frame_idx=ann_frame_idx,
                obj_id=objectnumint,
                box=box,
            )

        video_segments = {}
        for out_frame_idx, out_obj_ids, out_mask_logits in self.predictor_vid.propagate_in_video(inference_state):
            video_segments[out_frame_idx] = {
                out_obj_id: (out_mask_logits[i] > 0.0).cpu().numpy()
                for i, out_obj_id in enumerate(out_obj_ids)
            }

        if visualize:
            self.visualize_tracking(imgpath1, imgpath2, img1boxclasslist[0][0], video_segments)

        return video_segments

    def visualize_tracking(self, imgpath1, imgpath2, box, video_segments):
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
        
        # Original image with box
        ax1.imshow(Image.open(imgpath1))
        ax1.set_title("Original image object")
        xmin, xmax, ymin, ymax = box
        self.show_box([xmin, ymin, xmax, ymax], ax1)
        
        # Test image with detected mask
        ax2.imshow(Image.open(imgpath2))
        ax2.set_title("Detected object in test image")
        for out_obj_id, out_mask in video_segments[1].items():
            self.show_mask(out_mask, ax2, obj_id=out_obj_id)
        
        plt.show()

    @staticmethod
    def process_img_png_mask(img_path, mask_path, visualize=False):
        mask = Image.open(mask_path).convert("L")
        mask_np = np.array(mask)

        y_indices, x_indices = np.where(mask_np > 0)
        
        if y_indices.size > 0 and x_indices.size > 0:
            xmin, xmax = x_indices.min(), x_indices.max()
            ymin, ymax = y_indices.min(), y_indices.max()
        else:
            xmin, xmax, ymin, ymax = 0, 0, 0, 0

        if visualize:
            fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
            ax1.imshow(Image.open(img_path))
            ax1.set_title("Original Image")
            ax2.imshow(mask_np, cmap='gray')
            ax2.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, 
                                        edgecolor='red', facecolor='none', linewidth=2))
            ax2.set_title("Mask with Bounding Box")
            plt.show()

        return xmin, xmax, ymin, ymax

    def process_category(self, category, data_dir, output_dir):
        self.create_if_not_exists(output_dir)
        
        # Directories for saving outputs
        pred_masks_dir = os.path.join(output_dir, f'{category}_Predicted_Masks')
        pred_bbox_dir = os.path.join(output_dir, f'{category}_Bounding_Boxes_Predicted')
        gt_bbox_dir = os.path.join(output_dir, f'{category}_Bounding_Boxes_Ground_Truth')
        
        for dir_path in [pred_masks_dir, pred_bbox_dir, gt_bbox_dir]:
            self.create_if_not_exists(dir_path)

        # Get the first image and its mask for training
        first_img_path = sorted(glob.glob(os.path.join(data_dir, f'{category}_*.jpg')))[0]
        first_img_mask_path = first_img_path.replace('.jpg', '_1_gt.png')
        
        # Extract the bounding box from the first image's mask
        xmin, xmax, ymin, ymax = self.process_img_png_mask(first_img_path, first_img_mask_path)

        # Process remaining images
        image_files = sorted(glob.glob(os.path.join(data_dir, f'{category}_*.jpg')))[1:]
        for img_path in image_files:
            # Predict mask
            op = self.track_item_boxes(first_img_path, img_path, [([xmin, xmax, ymin, ymax], 1)])
            relevant_mask = op[1][1]
            
            if relevant_mask.ndim > 2:
                relevant_mask = np.squeeze(relevant_mask)
            
            mask_to_save = (relevant_mask.astype(np.uint8) * 255)
            
            # Save predicted mask
            mask_name = os.path.basename(img_path).replace('.jpg', '_pred_mask.png')
            save_path = os.path.join(pred_masks_dir, mask_name)
            Image.fromarray(mask_to_save).save(save_path)
            
            # Calculate and save predicted bounding box
            y_indices, x_indices = np.where(mask_to_save > 0)
            if y_indices.size > 0 and x_indices.size > 0:
                xmin, xmax = x_indices.min(), x_indices.max()
                ymin, ymax = y_indices.min(), y_indices.max()
                bbox = [xmin, ymin, xmax-xmin, ymax-ymin]
            else:
                bbox = [0, 0, 0, 0]
            
            self.save_bbox_coco_format(os.path.basename(img_path), bbox, 1, 
                                       os.path.join(pred_bbox_dir, f'{os.path.basename(img_path).replace(".jpg", "_pred_bbox.json")}'))
            
            # Calculate and save ground truth bounding box
            gt_mask_path = img_path.replace('.jpg', '_1_gt.png')
            if os.path.exists(gt_mask_path):
                xmin, xmax, ymin, ymax = self.process_img_png_mask(img_path, gt_mask_path)
                bbox = [xmin, ymin, xmax-xmin, ymax-ymin]
                self.save_bbox_coco_format(os.path.basename(img_path), bbox, 1, 
                                           os.path.join(gt_bbox_dir, f'{os.path.basename(img_path).replace(".jpg", "_gt_bbox.json")}'))
        
        # Evaluate predictions
        self.evaluate_category(category, gt_bbox_dir, pred_bbox_dir)

    @staticmethod
    def save_bbox_coco_format(img_name, bbox, category_id, output_path):
        bbox = [int(coord) for coord in bbox]
        annotation = {
            "image_id": img_name,
            "category_id": category_id,
            "bbox": bbox,
            "area": bbox[2] * bbox[3],
            "iscrowd": 0,
        }
        with open(output_path, 'w') as f:
            json.dump(annotation, f)

    @staticmethod
    def load_annotations_from_directory(directory):
        annotations = []
        for file_path in glob.glob(f'{directory}/*.json'):
            with open(file_path, 'r') as file:
                annotations.append(json.load(file))
        return annotations

    @staticmethod
    def convert_to_coco_format(annotations, image_ids, category_id, is_pred=False):
        coco_annotations = []
        for i, ann in enumerate(annotations):
            coco_annotation = {
                "id": i + 1,
                "image_id": image_ids.index(ann['image_id']),
                "category_id": category_id,
                "bbox": ann['bbox'],
                "area": ann['area'],
                "iscrowd": ann['iscrowd']
            }
            if is_pred:
                coco_annotation["score"] = 1.0  # Assuming high confidence for all predictions
            coco_annotations.append(coco_annotation)
        return coco_annotations

    #Evaluation
    def evaluate_category(self, category, gt_bbox_dir, pred_bbox_dir):
        gt_annotations = self.load_annotations_from_directory(gt_bbox_dir)
        pred_annotations = self.load_annotations_from_directory(pred_bbox_dir)
        
        image_ids = list({ann['image_id'] for ann in gt_annotations + pred_annotations})
        
        coco_gt = COCO()
        coco_pred = COCO()

        coco_gt.dataset = {
            'images': [{'id': idx, 'file_name': img_id} for idx, img_id in enumerate(image_ids)],
            'annotations': self.convert_to_coco_format(gt_annotations, image_ids, 1),
            'categories': [{'id': 1, 'name': category}]
        }
        
        coco_pred.dataset = {
            'images': [{'id': idx, 'file_name': img_id} for idx, img_id in enumerate(image_ids)],
            'annotations': self.convert_to_coco_format(pred_annotations, image_ids, 1, is_pred=True),
            'categories': [{'id': 1, 'name': category}]
        }

        coco_gt.createIndex()
        coco_pred.createIndex()

        coco_eval = COCOeval(coco_gt, coco_pred, 'bbox')
        coco_eval.evaluate()
        coco_eval.accumulate()
        coco_eval.summarize()

        print(f"Evaluation results for category: {category}")
        

    def run_pipeline(self, categories, data_dir, output_dir):
        for category in categories:
            print(f"Processing category: {category}")
            self.process_category(category, data_dir, output_dir)
            print(f"Finished processing category: {category}\n")

# %% [markdown]
# ### Initializing and Running the Pipeline

# %%
# Initialize the pipeline
model_cfg = "./sam2_hiera_t.yaml"
checkpoint = "./model/sam2_hiera_tiny.pt"
data_dir = "./data/data_2D"
output_dir = "./outputs"

pipeline = ImageSegmentationPipeline(model_cfg, checkpoint)

# %% [markdown]
# #### Category: can_chowder

# %%
categories = ["can_chowder"]

# Run the pipeline
pipeline.run_pipeline(categories, data_dir, output_dir)
# Out:
# Processing category: can_chowder
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  5.63it/s]
# C:\Users\HP\Desktop\Parallel_dots_assignment\segment-anything-2\sam2\modeling\backbones\hieradet.py:68: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   x = F.scaled_dot_product_attention(
# C:\Users\HP\Desktop\Parallel_dots_assignment\segment-anything-2\sam2\sam2_video_predictor.py:873: UserWarning: cannot import name '_C' from 'sam2' (C:\Users\HP\Desktop\Parallel_dots_assignment\segment-anything-2\sam2\__init__.py)
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/segment-anything-2/blob/main/INSTALL.md).
#   pred_masks_gpu = fill_holes_in_mask_scores(
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 14.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.71it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.76it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.81it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.71it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.67it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.98it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.37it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 13.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.57it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.47it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  2.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  4.31it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.80it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.16it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.91it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.29it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.36it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.71it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.12it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.92it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.12it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.78it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  2.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.38it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  5.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.53it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.66it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.18it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.49it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.71it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.87it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.98it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.57it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.16it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.91it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.57it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.08it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.78it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.10s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.185
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.183
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
# Evaluation results for category: can_chowder
# Finished processing category: can_chowder

# %% [markdown]
# #### Category: can_soymilk

# %%
categories = ["can_soymilk"]

# Run the pipeline
pipeline.run_pipeline(categories, data_dir, output_dir)
# Out:
# Processing category: can_soymilk
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.25it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.93it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.53it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.32it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.82it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.76it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.78it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.32it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 14.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.12it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.21it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.35it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.76it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.031
# Evaluation results for category: can_soymilk
# Finished processing category: can_soymilk

# %% [markdown]
# #### Category: can_tomatosoup

# %%
categories = ["can_tomatosoup"]

# Run the pipeline
pipeline.run_pipeline(categories, data_dir, output_dir)
# Out:
# Processing category: can_tomatosoup
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.84it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.07it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.29it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.23it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.29it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.54it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.76it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.70it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.65it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.96it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.24it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.30it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.74it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.50it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 13.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.82it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.37it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.96it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.84it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.87it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.84it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.49it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.24it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.025
# Evaluation results for category: can_tomatosoup
# Finished processing category: can_tomatosoup

# %% [markdown]
# #### Category: carton_oj

# %%
categories = ["carton_oj"]

# Run the pipeline
pipeline.run_pipeline(categories, data_dir, output_dir)
# Out:
# Processing category: carton_oj
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.12it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.72it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.21it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.80it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.81it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.21it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.12it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.24it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.33it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.010
# Evaluation results for category: carton_oj
# Finished processing category: carton_oj

# %% [markdown]
# #### Category: carton_soymilk

# %%
categories = ["carton_soymilk"]

# Run the pipeline
pipeline.run_pipeline(categories, data_dir, output_dir)
# Out:
# Processing category: carton_soymilk
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 13.47it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.51it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 13.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.32it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.66it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.78it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.71it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.23it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.73it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.53it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.03it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.40it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.21it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.41it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.27it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.85it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.81it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 13.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.16it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  5.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.08it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.08it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.017
# Evaluation results for category: carton_soymilk
# Finished processing category: carton_soymilk

# %% [markdown]
# #### Category: diet_coke

# %%
categories = ["diet_coke"]

# Run the pipeline
pipeline.run_pipeline(categories, data_dir, output_dir)
# Out:
# Processing category: diet_coke
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.16it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.39it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.38it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.30it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.41it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.91it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.90it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.82it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.97it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.40it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.94it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.21it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.30it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.95it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.38it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.71it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.65it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.84it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.25it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.48it/s]
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.076
# Evaluation results for category: diet_coke
# Finished processing category: diet_coke

# %% [markdown]
# #### Category: hc_potroastsoup

# %%
categories = ["hc_potroastsoup"]

# Run the pipeline
pipeline.run_pipeline(categories, data_dir, output_dir)
# Out:
# Processing category: hc_potroastsoup
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.64it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.80it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.78it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.89it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.25it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.76it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.85it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.24it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.82it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.09it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.60it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.83it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.87it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.52it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.87it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.55it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.84it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.16it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.84it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.05it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.71it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.19it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.41it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.84it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.59it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.07it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.12it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.56it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.50it/s]
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.045
# Evaluation results for category: hc_potroastsoup
# Finished processing category: hc_potroastsoup

# %% [markdown]
# #### Category: juicebox

# %%
categories = ["juicebox"]

# Run the pipeline
pipeline.run_pipeline(categories, data_dir, output_dir)
# Out:
# Processing category: juicebox
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.36it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.63it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.12it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.32it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.79it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.34it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.41it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.49it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.85it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.05it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.71it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.60it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.67it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.42it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.04it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.22it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.17it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.73it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.71it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.93it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.22it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.25it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.42it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.80it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.10it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.26it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.08it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.64it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.63it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.14it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.96it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.68it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.33it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.06it/s]
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.041
# Evaluation results for category: juicebox
# Finished processing category: juicebox

# %% [markdown]
# #### Category: rice_tuscan

# %%
categories = ["rice_tuscan"]

# Run the pipeline
pipeline.run_pipeline(categories, data_dir, output_dir)
# Out:
# Processing category: rice_tuscan
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  5.02it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.79it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.72it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.21it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.07it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.21it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.18it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.18it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.54it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.52it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.41it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.94it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.48it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.28it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.10it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  5.43it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.58it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.39it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.04it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.06it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.68it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.97it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.98it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.23it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.62it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.75it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.32it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.50it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  6.74it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.98it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.44it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 13.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.32it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.20it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.70it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.91it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.29it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.06it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.48it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.77it/s]
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.031
# Evaluation results for category: rice_tuscan
# Finished processing category: rice_tuscan

# %% [markdown]
# #### Category: ricepilaf

# %%
categories = ["ricepilaf"]

# Run the pipeline
pipeline.run_pipeline(categories, data_dir, output_dir)
# Out:
# Processing category: ricepilaf
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.32it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.62it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.56it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.57it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.47it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.13it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.99it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.93it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.19it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.95it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.02it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.75it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.77it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.11it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.57it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.55it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.86it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.59it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.18it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.11it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.45it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.66it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.09it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.16it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.88it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.85it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.77it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.15it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.26it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.96it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.61it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.35it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.43it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.96it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.69it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 12.01it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.83it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.89it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.27it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.31it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 11.76it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  3.94it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.90it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.81it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.92it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.20it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.51it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  9.34it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00, 10.46it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  8.08it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# frame loading (JPEG): 100%|██████████| 2/2 [00:00<00:00,  7.03it/s]
# propagate in video: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s]
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Evaluation results for category: ricepilaf
# Finished processing category: ricepilaf

# %% [markdown]
# ### Conclusion
#
# This project provides a solution for object tracking and image segmentation using the SAM2 model. The pipeline's modular design allows for easy adaptation to different categories.
